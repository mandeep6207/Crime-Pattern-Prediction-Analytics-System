# %% [markdown]
# # CrimeMind AI
# Crime Pattern Prediction and Crime Intelligence Analytics System
#
# This notebook runs the full CrimeMind AI workflow: data cleaning, feature engineering, visualization, model training, metrics export, and report generation.

# %%
from pathlib import Path
import sys

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
from src.crimemind import load_dataset, clean_dataset, engineer_features, summarize_data

data = load_dataset()
clean = clean_dataset(data)
features = engineer_features(clean)
summary = summarize_data(clean)
summary

# %%
from src.crimemind import run_pipeline

artifacts = run_pipeline()
artifacts.best_model_name

# %% [markdown]
# The pipeline writes outputs into `models/`, `reports/`, `metrics/`, and `visuals/`.
